# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('interview.csv')
df.head(3)
# Out:
#   Date of Interview Client name         Industry Location  \
# 0        13.02.2015     Hospira  Pharmaceuticals  Chennai
# 1        13.02.2015     Hospira  Pharmaceuticals  Chennai
# 2        13.02.2015     Hospira  Pharmaceuticals  Chennai
#
#   Position to be closed Nature of Skillset    Interview Type Name(Cand ID)  \
# 0   Production- Sterile            Routine  Scheduled Walkin   Candidate 1
# 1   Production- Sterile            Routine  Scheduled Walkin   Candidate 2
# 2   Production- Sterile            Routine  Scheduled Walkin   Candidate 3
#
#   Gender Candidate Current Location  ...  \
# 0   Male                    Chennai  ...
# 1   Male                    Chennai  ...
# 2   Male                    Chennai  ...
#
#   Are you clear with the venue details and the landmark.  \
# 0                                                Yes
# 1                                                Yes
# 2                                                NaN
#
#   Has the call letter been shared Expected Attendance Observed Attendance  \
# 0                             Yes                 Yes                  No
# 1                             Yes                 Yes                  No
# 2                             NaN           Uncertain                  No
#
#   Marital Status Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27
# 0         Single         NaN         NaN         NaN         NaN         NaN
# 1         Single         NaN         NaN         NaN         NaN         NaN
# 2         Single         NaN         NaN         NaN         NaN         NaN
#
# [3 rows x 28 columns]

# %%
df.shape
# Out:
# (1234, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 28 columns):
# Date of Interview                                                                                     1233 non-null object
# Client name                                                                                           1234 non-null object
# Industry                                                                                              1233 non-null object
# Location                                                                                              1233 non-null object
# Position to be closed                                                                                 1233 non-null object
# Nature of Skillset                                                                                    1233 non-null object
# Interview Type                                                                                        1233 non-null object
# Name(Cand ID)                                                                                         1233 non-null object
# Gender                                                                                                1233 non-null object
# Candidate Current Location                                                                            1233 non-null object
# Candidate Job Location                                                                                1233 non-null object
# Interview Venue                                                                                       1233 non-null object
# Candidate Native location                                                                             1233 non-null object
# Have you obtained the necessary permission to start at the required time                              1029 non-null object
# Hope there will be no unscheduled meetings                                                            986 non-null object
# Can I Call you three hours before the interview and follow up on your attendance for the interview    986 non-null object
# Can I have an alternative number/ desk number. I assure you that I will not trouble you too much      986 non-null object
# Have you taken a printout of your updated resume. Have you read the JD and understood the same        985 non-null object
# Are you clear with the venue details and the landmark.                                                985 non-null object
# Has the call letter been shared                                                                       988 non-null object
# Expected Attendance                                                                                   1228 non-null object
# Observed Attendance                                                                                   1233 non-null object
# Marital Status                                                                                        1233 non-null object
# Unnamed: 23                                                                                           0 non-null float64
# Unnamed: 24                                                                                           0 non-null float64
# Unnamed: 25                                                                                           0 non-null float64
# Unnamed: 26                                                                                           0 non-null float64
# Unnamed: 27                                                                                           0 non-null float64
# dtypes: float64(5), object(23)
# memory usage: 270.0+ KB

# %%
df.columns
# Out:
# Index(['Date of Interview', 'Client name', 'Industry', 'Location',
#        'Position to be closed', 'Nature of Skillset', 'Interview Type',
#        'Name(Cand ID)', 'Gender', 'Candidate Current Location',
#        'Candidate Job Location', 'Interview Venue',
#        'Candidate Native location',
#        'Have you obtained the necessary permission to start at the required time',
#        'Hope there will be no unscheduled meetings',
#        'Can I Call you three hours before the interview and follow up on your attendance for the interview',
#        'Can I have an alternative number/ desk number. I assure you that I will not trouble you too much',
#        'Have you taken a printout of your updated resume. Have you read the JD and understood the same',
#        'Are you clear with the venue details and the landmark.',
#        'Has the call letter been shared', 'Expected Attendance',
#        'Observed Attendance', 'Marital Status', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27'],
#       dtype='object')

# %% [markdown]
# ### Delete the insignificant columns

# %%
df.drop(['Unnamed: 23', 'Unnamed: 24',
       'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (1234, 23)

# %%
df.drop(['Date of Interview', 'Name(Cand ID)'], axis=1, inplace=True)    #Insignicant info

# %%
df.shape
# Out:
# (1234, 21)

# %%
df.head()
df.columns
# Out:
# Index(['Client name', 'Industry', 'Location', 'Position to be closed',
#        'Nature of Skillset', 'Interview Type', 'Gender',
#        'Candidate Current Location', 'Candidate Job Location',
#        'Interview Venue', 'Candidate Native location',
#        'Have you obtained the necessary permission to start at the required time',
#        'Hope there will be no unscheduled meetings',
#        'Can I Call you three hours before the interview and follow up on your attendance for the interview',
#        'Can I have an alternative number/ desk number. I assure you that I will not trouble you too much',
#        'Have you taken a printout of your updated resume. Have you read the JD and understood the same',
#        'Are you clear with the venue details and the landmark.',
#        'Has the call letter been shared', 'Expected Attendance',
#        'Observed Attendance', 'Marital Status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 21 columns):
# Client name                                                                                           1234 non-null object
# Industry                                                                                              1233 non-null object
# Location                                                                                              1233 non-null object
# Position to be closed                                                                                 1233 non-null object
# Nature of Skillset                                                                                    1233 non-null object
# Interview Type                                                                                        1233 non-null object
# Gender                                                                                                1233 non-null object
# Candidate Current Location                                                                            1233 non-null object
# Candidate Job Location                                                                                1233 non-null object
# Interview Venue                                                                                       1233 non-null object
# Candidate Native location                                                                             1233 non-null object
# Have you obtained the necessary permission to start at the required time                              1029 non-null object
# Hope there will be no unscheduled meetings                                                            986 non-null object
# Can I Call you three hours before the interview and follow up on your attendance for the interview    986 non-null object
# Can I have an alternative number/ desk number. I assure you that I will not trouble you too much      986 non-null object
# Have you taken a printout of your updated resume. Have you read the JD and understood the same        985 non-null object
# Are you clear with the venue details and the landmark.                                                985 non-null object
# Has the call letter been shared                                                                       988 non-null object
# Expected Attendance                                                                                   1228 non-null object
# Observed Attendance                                                                                   1233 non-null object
# Marital Status                                                                                        1233 non-null object
# dtypes: object(21)
# memory usage: 202.5+ KB

# %% [markdown]
# ## Data Munging

# %%
df['Client name'].unique()
# Out:
# array(['Hospira', 'Aon Hewitt', 'UST', 'Standard Chartered Bank', 'ANZ',
#        'Pfizer', 'Standard Chartered Bank Chennai', 'Aon hewitt Gurgaon',
#        'Astrazeneca', 'Flextronics', 'Prodapt', 'Williams Lea',
#        'Barclays', 'Hewitt', 'Woori Bank', '\ufeff\ufeff'], dtype=object)

# %%
df.index[(df['Client name'] == '\ufeff\ufeff')]
df.drop(df.index[(df['Client name'] == '\ufeff\ufeff')], inplace = True, axis = 0) 
df['Client name'].replace(  to_replace=[ 'Aon Hewitt', 'Aon hewitt Gurgaon', 'Hewitt'],value='IT', inplace=True)
df['Client name'].replace(  to_replace=['Standard Chartered Bank', 'Standard Chartered Bank Chennai'],value='Standard Chartered Bank', inplace=True)
df['Client name'].value_counts()
# Out:
# Standard Chartered Bank    921
# Hospira                     75
# Pfizer                      75
# IT                          50
# Flextronics                 23
# ANZ                         22
# UST                         18
# Prodapt                     17
# Astrazeneca                 15
# Williams Lea                11
# Barclays                     5
# Woori Bank                   1
# Name: Client name, dtype: int64

# %%
df['Industry'].unique()
# Out:
# array(['Pharmaceuticals', 'IT Services', 'BFSI',
#        'IT Products and Services', 'Electronics', 'Telecom', 'IT'],
#       dtype=object)

# %%
df['Industry'].replace(  to_replace=['IT Services', 'IT Products and Services', 'IT'],value='IT', inplace=True)
df['Industry'].value_counts()
# Out:
# BFSI               949
# Pharmaceuticals    165
# IT                  79
# Electronics         23
# Telecom             17
# Name: Industry, dtype: int64

# %%
df['Location'].unique()
# Out:
# array(['Chennai', 'Gurgaon', 'Bangalore', 'Hyderabad', 'Gurgaonr',
#        'Delhi', 'chennai', '- Cochin- ', 'Noida', 'CHENNAI', 'chennai '],
#       dtype=object)

# %% [markdown]
# Fix the spellings

# %%
df['Location'].replace(  to_replace=['Gurgaonr','Delhi', 'Noida'],value='Gurgaon', inplace=True)  #Grouping Delhi Noida Gurgaon
df['Location'].replace(  to_replace=['CHENNAI', 'chennai ','chennai'],value='Chennai', inplace=True)
df['Location'].unique()
# Out:
# array(['Chennai', 'Gurgaon', 'Bangalore', 'Hyderabad', '- Cochin- '],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Client name', 'Industry', 'Location', 'Position to be closed',
#        'Nature of Skillset', 'Interview Type', 'Gender',
#        'Candidate Current Location', 'Candidate Job Location',
#        'Interview Venue', 'Candidate Native location',
#        'Have you obtained the necessary permission to start at the required time',
#        'Hope there will be no unscheduled meetings',
#        'Can I Call you three hours before the interview and follow up on your attendance for the interview',
#        'Can I have an alternative number/ desk number. I assure you that I will not trouble you too much',
#        'Have you taken a printout of your updated resume. Have you read the JD and understood the same',
#        'Are you clear with the venue details and the landmark.',
#        'Has the call letter been shared', 'Expected Attendance',
#        'Observed Attendance', 'Marital Status'],
#       dtype='object')

# %%
df['Position to be closed'].unique()
# Out:
# array(['Production- Sterile', 'Selenium testing', 'Dot Net', 'AML',
#        'Trade Finance', 'Routine', 'Niche'], dtype=object)

# %%
df['Nature of Skillset'].unique()
# Out:
# array(['Routine', 'Oracle', 'Accounting Operations', 'Banking Operations',
#        'Fresher', 'AML/KYC/CDD', 'CDD KYC', 'Biosimiliars', 'RA Label',
#        'RA Publishing', 'EMEA', 'LCM -Manager', 'Licensing – RA',
#        'generic drugs – RA', 'Biosimilars', 'Regulatory',
#        'Analytical R & D', 'Analytical R&D',
#        'Senior software engineer-Mednet', 'Tech lead-Mednet',
#        'Tech Lead- Mednet', 'Technical Lead', 'Sr Automation Testing',
#        'TL', 'Senior Analyst', 'production', 'Production', 'Core Java',
#        'Java J2EE', 'Oracle Plsql', 'Java,SQL', 'Automation Testing Java',
#        'Submission Management', 'Biosimillar', 'Publishing',
#        'Global Labelling', 'ALS Testing', 'Java Developer',
#        'Lending and Liabilities', 'Lending & Liability',
#        'Lending And Liabilities', 'L & L', 'Banking operations',
#        'Lending&Liablities', 'JAVA/J2EE/Struts/Hibernate',
#        'JAVA/SPRING/HIBERNATE/JSF', 'Java', 'Java JSF', 'Java,J2ee, JSF',
#        'Java ,J2ee', 'Java J2ee', '11.30 AM', '10.00 AM', '9.00 Am',
#        '12.30 Pm', '9.30 AM', '11.30 Am', 'Java, J2Ee', 'Java,J2EE',
#        'Java/J2ee/Core Java', 'Java/J2ee', 'JAVA, J2ee', 'JAVA,J2ee',
#        'T-24 developer', 'COTS Developer', 'Product Control', 'Dot Net',
#        'COTS', 'testing', '- SAPBO, Informatica', 'ETL', 'Java-SAS',
#        'Java Tech Lead', 'Manager', 'JAVA,SQL', 'Java, SQL', 'Hadoop',
#        'SCCM', 'SCCM-(Network, sharepoint,ms exchange)',
#        'SCCm- Desktop support', 'Sccm- networking', 'sccm', 'SCCM – SQL',
#        'SCCM – Sharepoint', 'Production Support - SCCM', 'SAS',
#        'BaseSAS Program/ Reporting', 'Java, Spring, Hibernate',
#        'Java,spring,hibernate', 'Java, XML, Struts, hibernate',
#        'JAVA/J2EE', 'Java '], dtype=object)

# %%
df[df['Nature of Skillset'].isin(['11.30 AM', '10.00 AM', '9.00 Am','12.30 Pm', '9.30 AM', '11.30 Am'])]  #Just to check the rows
# Out:
#                  Client name Industry Location Position to be closed  \
# 816  Standard Chartered Bank     BFSI  Chennai               Routine
# 817  Standard Chartered Bank     BFSI  Chennai               Routine
# 818  Standard Chartered Bank     BFSI  Chennai               Routine
# 819  Standard Chartered Bank     BFSI  Chennai               Routine
# 820  Standard Chartered Bank     BFSI  Chennai               Routine
# 821  Standard Chartered Bank     BFSI  Chennai               Routine
# 822  Standard Chartered Bank     BFSI  Chennai               Routine
#
#     Nature of Skillset     Interview Type  Gender Candidate Current Location  \
# 816           11.30 AM  Scheduled Walk In    Male                    chennai
# 817           10.00 AM  Scheduled Walk In    Male                    chennai
# 818            9.00 Am  Scheduled Walk In  Female                    chennai
# 819           12.30 Pm  Scheduled Walk In    Male                    chennai
# 820           11.30 AM  Scheduled Walk In    Male                    Chennai
# 821            9.30 AM  Scheduled Walk In    Male                    Chennai
# 822           11.30 Am  Scheduled Walk In    Male                    Chennai
#
#     Candidate Job Location Interview Venue  ...  \
# 816                Chennai         Chennai  ...
# 817                Chennai         Chennai  ...
# 818                Chennai         Chennai  ...
# 819                Chennai         Chennai  ...
# 820                Chennai         Chennai  ...
# 821                Chennai         Chennai  ...
# 822                Chennai         Chennai  ...
#
#     Have you obtained the necessary permission to start at the required time  \
# 816                                                NaN
# 817                                                Yes
# 818                                                Yes
# 819                                                NaN
# 820                                                Yes
# 821                                                Yes
# 822                                                NaN
#
#     Hope there will be no unscheduled meetings  \
# 816                                        NaN
# 817                                        Yes
# 818                                        Yes
# 819                                        NaN
# 820                                        Yes
# 821                                        Yes
# 822                                        NaN
#
#     Can I Call you three hours before the interview and follow up on your attendance for the interview  \
# 816                                                NaN
# 817                                                Yes
# 818                                                Yes
# 819                                                NaN
# 820                                                Yes
# 821                                                Yes
# 822                                                NaN
#
#     Can I have an alternative number/ desk number. I assure you that I will not trouble you too much  \
# 816                                                NaN
# 817                                                Yes
# 818                                                Yes
# 819                                                NaN
# 820                                                Yes
# 821                                                Yes
# 822                                                NaN
#
#     Have you taken a printout of your updated resume. Have you read the JD and understood the same  \
# 816                                                NaN
# 817                                                Yes
# 818                                                Yes
# 819                                                NaN
# 820                                                Yes
# 821                                                Yes
# 822                                                NaN
#
#     Are you clear with the venue details and the landmark.  \
# 816                                                NaN
# 817                                                Yes
# 818                                                Yes
# 819                                                NaN
# 820                                                Yes
# 821                                                Yes
# 822                                                NaN
#
#     Has the call letter been shared Expected Attendance Observed Attendance  \
# 816                             NaN           Uncertain                 Yes
# 817                             Yes                 Yes                  No
# 818                             Yes                 Yes                  No
# 819                             NaN           Uncertain                 Yes
# 820                             Yes                 Yes                 Yes
# 821                             Yes                 Yes                 Yes
# 822                             NaN           Uncertain                 yes
#
#     Marital Status
# 816         Single
# 817         Single
# 818        Married
# 819         Single
# 820         Single
# 821         Single
# 822         Single
#
# [7 rows x 21 columns]

# %%
df['Interview Type'].unique()
# Out:
# array(['Scheduled Walkin', 'Scheduled ', 'Walkin', 'Scheduled Walk In',
#        'Sceduled walkin', 'Walkin '], dtype=object)

# %%
df['Interview Type'].replace(['Scheduled Walk In','Sceduled walkin'],'Scheduled Walkin',inplace=True)
df['Interview Type'].replace(['Walkin '],'Walkin',inplace=True)
df['Interview Type'].unique()
# Out:
# array(['Scheduled Walkin', 'Scheduled ', 'Walkin'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Candidate Current Location'].unique()
# Out:
# array(['Chennai', 'Gurgaon', 'Bangalore', 'Hyderabad', 'Delhi', 'chennai',
#        '- Cochin- ', 'Noida', 'CHENNAI', 'chennai '], dtype=object)

# %%
df['Candidate Current Location'].replace(  to_replace=['CHENNAI', 'chennai ','chennai'],value='Chennai', inplace=True)
df['Candidate Current Location'].replace(  to_replace=['Gurgaonr','Delhi', 'Noida'],value='Gurgaon', inplace=True)
df['Candidate Current Location'].value_counts()
# Out:
# Chennai       844
# Bangalore     292
# Gurgaon        50
# Hyderabad      38
# - Cochin-       9
# Name: Candidate Current Location, dtype: int64

# %%
df['Candidate Job Location'].unique()
# Out:
# array(['Hosur', 'Bangalore', 'Chennai', 'Gurgaon', 'Visakapatinam',
#        '- Cochin- ', 'Noida'], dtype=object)

# %%
df['Candidate Job Location'].replace(  to_replace=['Gurgaonr','Delhi', 'Noida'],value='Gurgaon', inplace=True)
df['Candidate Job Location'].replace(  to_replace=['Hosur'],value='Bangalore', inplace=True)
df['Candidate Job Location'].value_counts()
# Out:
# Chennai          893
# Bangalore        260
# Gurgaon           50
# Visakapatinam     21
# - Cochin-          9
# Name: Candidate Job Location, dtype: int64

# %%
df['Interview Venue'].unique()
# Out:
# array(['Hosur', 'Gurgaon', 'Bangalore', 'Chennai', 'Hyderabad',
#        '- Cochin- ', 'Noida'], dtype=object)

# %%
df['Interview Venue'].replace(  to_replace=['Hosur'],value='Bangalore', inplace=True)
df['Interview Venue'].replace(  to_replace=['Gurgaonr','Delhi', 'Noida'],value='Gurgaon', inplace=True)
df['Interview Venue'].value_counts()
# Out:
# Chennai       852
# Bangalore     282
# Gurgaon        50
# Hyderabad      40
# - Cochin-       9
# Name: Interview Venue, dtype: int64

# %%
df['Candidate Native location'].unique()
# Out:
# array(['Hosur', 'Trichy', 'Chennai', 'Gurgaon', 'Noida', 'Delhi /NCR',
#        'Cochin', 'Trivandrum', 'Bangalore', 'Coimbatore', 'Salem',
#        'Tanjore', 'Hyderabad', 'Mumbai', 'Pune', 'Kolkata', 'Allahabad',
#        'Panjim', 'Cuttack', 'Visakapatinam', 'Belgaum', 'Patna',
#        'Chitoor', 'Anantapur', 'Warangal', 'Ahmedabad', 'Kurnool',
#        'Vijayawada', 'Vellore', 'Pondicherry', 'Nagercoil', 'Agra',
#        'Bhubaneshwar', 'Ghaziabad', 'Baddi', 'Tuticorin', 'Tirupati',
#        'Faizabad', 'Ambur', 'Chandigarh', 'Mysore', 'Hissar', 'Delhi',
#        'Kanpur', 'Lucknow', '- Cochin- '], dtype=object)

# %%
df['Candidate Native location'].replace(  to_replace=['Gurgaonr','Delhi', 'Noida','Delhi /NCR'],value='Gurgaon', inplace=True)
df['Candidate Native location'].replace(  to_replace=['Hosur'],value='Bangalore', inplace=True)
df['Candidate Native location'].unique()
# Out:
# array(['Bangalore', 'Trichy', 'Chennai', 'Gurgaon', 'Cochin',
#        'Trivandrum', 'Coimbatore', 'Salem', 'Tanjore', 'Hyderabad',
#        'Mumbai', 'Pune', 'Kolkata', 'Allahabad', 'Panjim', 'Cuttack',
#        'Visakapatinam', 'Belgaum', 'Patna', 'Chitoor', 'Anantapur',
#        'Warangal', 'Ahmedabad', 'Kurnool', 'Vijayawada', 'Vellore',
#        'Pondicherry', 'Nagercoil', 'Agra', 'Bhubaneshwar', 'Ghaziabad',
#        'Baddi', 'Tuticorin', 'Tirupati', 'Faizabad', 'Ambur',
#        'Chandigarh', 'Mysore', 'Hissar', 'Kanpur', 'Lucknow',
#        '- Cochin- '], dtype=object)

# %%
df['Have you obtained the necessary permission to start at the required time'].unique()
# Out:
# array(['Yes', nan, 'No', 'Not yet', 'Yet to confirm', 'NO', 'yes', 'Na'],
#       dtype=object)

# %%
df['Have you obtained the necessary permission to start at the required time'].replace(  to_replace=['yes'],value='Yes', inplace=True)
df['Have you obtained the necessary permission to start at the required time'].replace(  to_replace=['No', 'NO',],value='No', inplace=True)
df['Have you obtained the necessary permission to start at the required time'].replace(  to_replace=['Not yet', 'Yet to confirm'],value='Not yet', inplace=True)
df['Have you obtained the necessary permission to start at the required time'].value_counts()
# Out:
# Yes        921
# No          80
# Not yet     23
# Na           5
# Name: Have you obtained the necessary permission to start at the required time, dtype: int64

# %%
#To view the Nan
df.loc[df['Have you obtained the necessary permission to start at the required time'].isin(['Yes', 'No', 'Not yet', 'Na'])==False]
# Out:
#                   Client name         Industry   Location  \
# 2                     Hospira  Pharmaceuticals    Chennai
# 242   Standard Chartered Bank             BFSI  Bangalore
# 244   Standard Chartered Bank             BFSI  Bangalore
# 245   Standard Chartered Bank             BFSI  Bangalore
# 247   Standard Chartered Bank             BFSI  Bangalore
# 248   Standard Chartered Bank             BFSI  Bangalore
# 251   Standard Chartered Bank             BFSI  Bangalore
# 254   Standard Chartered Bank             BFSI  Bangalore
# 255   Standard Chartered Bank             BFSI  Bangalore
# 260   Standard Chartered Bank             BFSI  Bangalore
# 261   Standard Chartered Bank             BFSI  Bangalore
# 264   Standard Chartered Bank             BFSI  Bangalore
# 265   Standard Chartered Bank             BFSI  Bangalore
# 267   Standard Chartered Bank             BFSI  Bangalore
# 268   Standard Chartered Bank             BFSI  Bangalore
# 269   Standard Chartered Bank             BFSI  Bangalore
# 272   Standard Chartered Bank             BFSI  Bangalore
# 273   Standard Chartered Bank             BFSI  Bangalore
# 276   Standard Chartered Bank             BFSI  Bangalore
# 279   Standard Chartered Bank             BFSI  Bangalore
# 280   Standard Chartered Bank             BFSI  Bangalore
# 283   Standard Chartered Bank             BFSI  Bangalore
# 284   Standard Chartered Bank             BFSI  Bangalore
# 286   Standard Chartered Bank             BFSI  Bangalore
# 287   Standard Chartered Bank             BFSI  Bangalore
# 290   Standard Chartered Bank             BFSI  Bangalore
# 292   Standard Chartered Bank             BFSI  Bangalore
# 296   Standard Chartered Bank             BFSI  Bangalore
# 299   Standard Chartered Bank             BFSI  Bangalore
# 302   Standard Chartered Bank             BFSI  Bangalore
# ...                       ...              ...        ...
# 831   Standard Chartered Bank             BFSI    Chennai
# 835   Standard Chartered Bank             BFSI    Chennai
# 841   Standard Chartered Bank             BFSI    Chennai
# 846   Standard Chartered Bank             BFSI    Chennai
# 847   Standard Chartered Bank             BFSI    Chennai
# 869   Standard Chartered Bank             BFSI    Chennai
# 871   Standard Chartered Bank             BFSI    Chennai
# 876   Standard Chartered Bank             BFSI    Chennai
# 880   Standard Chartered Bank             BFSI    Chennai
# 1002                       IT               IT    Gurgaon
# 1045  Standard Chartered Bank             BFSI  Bangalore
# 1048  Standard Chartered Bank             BFSI  Bangalore
# 1049  Standard Chartered Bank             BFSI  Bangalore
# 1050  Standard Chartered Bank             BFSI  Bangalore
# 1051  Standard Chartered Bank             BFSI  Bangalore
# 1053  Standard Chartered Bank             BFSI  Bangalore
# 1055  Standard Chartered Bank             BFSI  Bangalore
# 1059  Standard Chartered Bank             BFSI  Bangalore
# 1060  Standard Chartered Bank             BFSI  Bangalore
# 1061  Standard Chartered Bank             BFSI  Bangalore
# 1065  Standard Chartered Bank             BFSI  Bangalore
# 1071  Standard Chartered Bank             BFSI    Chennai
# 1077  Standard Chartered Bank             BFSI    Chennai
# 1080  Standard Chartered Bank             BFSI    Chennai
# 1081  Standard Chartered Bank             BFSI    Chennai
# 1083  Standard Chartered Bank             BFSI    Chennai
# 1086  Standard Chartered Bank             BFSI    Chennai
# 1087  Standard Chartered Bank             BFSI    Chennai
# 1088  Standard Chartered Bank             BFSI    Chennai
# 1232                   Pfizer  Pharmaceuticals    Chennai
#
#      Position to be closed          Nature of Skillset    Interview Type  \
# 2      Production- Sterile                     Routine  Scheduled Walkin
# 242                Routine                 AML/KYC/CDD  Scheduled Walkin
# 244                Routine                 AML/KYC/CDD  Scheduled Walkin
# 245                Routine                 AML/KYC/CDD  Scheduled Walkin
# 247                Routine                 AML/KYC/CDD  Scheduled Walkin
# 248                Routine                 AML/KYC/CDD  Scheduled Walkin
# 251                Routine                 AML/KYC/CDD  Scheduled Walkin
# 254                Routine                 AML/KYC/CDD  Scheduled Walkin
# 255                Routine                 AML/KYC/CDD  Scheduled Walkin
# 260                Routine                 AML/KYC/CDD  Scheduled Walkin
# 261                Routine                 AML/KYC/CDD  Scheduled Walkin
# 264                Routine                 AML/KYC/CDD  Scheduled Walkin
# 265                Routine                 AML/KYC/CDD  Scheduled Walkin
# 267                Routine                 AML/KYC/CDD  Scheduled Walkin
# 268                Routine                 AML/KYC/CDD  Scheduled Walkin
# 269                Routine                 AML/KYC/CDD  Scheduled Walkin
# 272                Routine                 AML/KYC/CDD  Scheduled Walkin
# 273                Routine                 AML/KYC/CDD  Scheduled Walkin
# 276                Routine                 AML/KYC/CDD  Scheduled Walkin
# 279                Routine                 AML/KYC/CDD  Scheduled Walkin
# 280                Routine                 AML/KYC/CDD  Scheduled Walkin
# 283                Routine                 AML/KYC/CDD  Scheduled Walkin
# 284                Routine                 AML/KYC/CDD  Scheduled Walkin
# 286                Routine                 AML/KYC/CDD  Scheduled Walkin
# 287                Routine                 AML/KYC/CDD  Scheduled Walkin
# 290                Routine                 AML/KYC/CDD  Scheduled Walkin
# 292                Routine                 AML/KYC/CDD  Scheduled Walkin
# 296                Routine                 AML/KYC/CDD  Scheduled Walkin
# 299                Routine                 AML/KYC/CDD  Scheduled Walkin
# 302                Routine                 AML/KYC/CDD  Scheduled Walkin
# ...                    ...                         ...               ...
# 831                Routine                   Java J2ee  Scheduled Walkin
# 835                Routine         Java/J2ee/Core Java        Scheduled
# 841                Routine                        Java        Scheduled
# 846                Routine                  JAVA, J2ee        Scheduled
# 847                Routine                   JAVA,J2ee        Scheduled
# 869                Routine   JAVA/SPRING/HIBERNATE/JSF            Walkin
# 871                Routine   JAVA/SPRING/HIBERNATE/JSF            Walkin
# 876                Routine                    Java JSF            Walkin
# 880                Routine              Java,J2ee, JSF            Walkin
# 1002               Routine                   Java, SQL        Scheduled
# 1045               Routine                         SAS        Scheduled
# 1048               Routine                         SAS        Scheduled
# 1049               Routine                         SAS        Scheduled
# 1050               Routine                         SAS        Scheduled
# 1051               Routine                         SAS        Scheduled
# 1053               Routine                         SAS        Scheduled
# 1055               Routine                         SAS        Scheduled
# 1059               Routine                         SAS        Scheduled
# 1060               Routine                         SAS        Scheduled
# 1061               Routine                         SAS        Scheduled
# 1065               Routine                         SAS        Scheduled
# 1071               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walkin
# 1077               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walkin
# 1080               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walkin
# 1081               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walkin
# 1083               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walkin
# 1086               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walkin
# 1087               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walkin
# 1088               Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walkin
# 1232                 Niche          generic drugs – RA        Scheduled
#
#       Gender Candidate Current Location Candidate Job Location  \
# 2       Male                    Chennai                Chennai
# 242     Male                  Bangalore              Bangalore
# 244     Male                  Bangalore              Bangalore
# 245     Male                  Bangalore              Bangalore
# 247   Female                  Bangalore              Bangalore
# 248   Female                  Bangalore              Bangalore
# 251     Male                  Bangalore              Bangalore
# 254     Male                  Bangalore              Bangalore
# 255     Male                  Bangalore              Bangalore
# 260     Male                  Bangalore              Bangalore
# 261     Male                  Bangalore              Bangalore
# 264     Male                  Bangalore              Bangalore
# 265   Female                  Bangalore              Bangalore
# 267     Male                  Bangalore              Bangalore
# 268     Male                  Bangalore              Bangalore
# 269     Male                  Bangalore              Bangalore
# 272     Male                  Bangalore              Bangalore
# 273     Male                  Bangalore              Bangalore
# 276   Female                  Bangalore              Bangalore
# 279     Male                  Bangalore              Bangalore
# 280   Female                  Bangalore              Bangalore
# 283     Male                  Bangalore              Bangalore
# 284     Male                  Bangalore              Bangalore
# 286     Male                  Bangalore              Bangalore
# 287     Male                  Bangalore              Bangalore
# 290   Female                  Bangalore              Bangalore
# 292     Male                  Bangalore              Bangalore
# 296     Male                  Bangalore              Bangalore
# 299     Male                  Bangalore              Bangalore
# 302     Male                  Bangalore              Bangalore
# ...      ...                        ...                    ...
# 831     Male                    Chennai                Chennai
# 835   Female                    Chennai                Chennai
# 841     Male                    Chennai                Chennai
# 846     Male                    Chennai                Chennai
# 847     Male                    Chennai                Chennai
# 869     Male                    Chennai                Chennai
# 871     Male                    Chennai                Chennai
# 876     Male                    Chennai                Chennai
# 880     Male                    Chennai                Chennai
# 1002    Male                    Gurgaon                Gurgaon
# 1045    Male                  Bangalore              Bangalore
# 1048    Male                  Bangalore              Bangalore
# 1049    Male                  Bangalore              Bangalore
# 1050    Male                  Bangalore              Bangalore
# 1051    Male                  Bangalore              Bangalore
# 1053    Male                  Bangalore              Bangalore
# 1055    Male                  Bangalore              Bangalore
# 1059    Male                  Bangalore              Bangalore
# 1060    Male                  Bangalore              Bangalore
# 1061    Male                  Bangalore              Bangalore
# 1065  Female                  Bangalore              Bangalore
# 1071    Male                    Chennai                Chennai
# 1077    Male                    Chennai                Chennai
# 1080    Male                    Chennai                Chennai
# 1081    Male                    Chennai                Chennai
# 1083  Female                    Chennai                Chennai
# 1086  Female                    Chennai                Chennai
# 1087    Male                    Chennai                Chennai
# 1088    Male                    Chennai                Chennai
# 1232  Female                    Chennai                Chennai
#
#      Interview Venue  ...  \
# 2          Bangalore  ...
# 242        Bangalore  ...
# 244        Bangalore  ...
# 245        Bangalore  ...
# 247        Bangalore  ...
# 248        Bangalore  ...
# 251        Bangalore  ...
# 254        Bangalore  ...
# 255        Bangalore  ...
# 260        Bangalore  ...
# 261        Bangalore  ...
# 264        Bangalore  ...
# 265        Bangalore  ...
# 267        Bangalore  ...
# 268        Bangalore  ...
# 269        Bangalore  ...
# 272        Bangalore  ...
# 273        Bangalore  ...
# 276        Bangalore  ...
# 279        Bangalore  ...
# 280        Bangalore  ...
# 283        Bangalore  ...
# 284        Bangalore  ...
# 286        Bangalore  ...
# 287        Bangalore  ...
# 290        Bangalore  ...
# 292        Bangalore  ...
# 296        Bangalore  ...
# 299        Bangalore  ...
# 302        Bangalore  ...
# ...              ...  ...
# 831          Chennai  ...
# 835          Chennai  ...
# 841          Chennai  ...
# 846          Chennai  ...
# 847          Chennai  ...
# 869          Chennai  ...
# 871          Chennai  ...
# 876          Chennai  ...
# 880          Chennai  ...
# 1002         Gurgaon  ...
# 1045       Bangalore  ...
# 1048       Bangalore  ...
# 1049       Bangalore  ...
# 1050       Bangalore  ...
# 1051       Bangalore  ...
# 1053       Bangalore  ...
# 1055       Bangalore  ...
# 1059       Bangalore  ...
# 1060       Bangalore  ...
# 1061       Bangalore  ...
# 1065       Bangalore  ...
# 1071         Chennai  ...
# 1077         Chennai  ...
# 1080         Chennai  ...
# 1081         Chennai  ...
# 1083         Chennai  ...
# 1086         Chennai  ...
# 1087         Chennai  ...
# 1088         Chennai  ...
# 1232         Chennai  ...
#
#      Have you obtained the necessary permission to start at the required time  \
# 2                                                   NaN
# 242                                                 NaN
# 244                                                 NaN
# 245                                                 NaN
# 247                                                 NaN
# 248                                                 NaN
# 251                                                 NaN
# 254                                                 NaN
# 255                                                 NaN
# 260                                                 NaN
# 261                                                 NaN
# 264                                                 NaN
# 265                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 272                                                 NaN
# 273                                                 NaN
# 276                                                 NaN
# 279                                                 NaN
# 280                                                 NaN
# 283                                                 NaN
# 284                                                 NaN
# 286                                                 NaN
# 287                                                 NaN
# 290                                                 NaN
# 292                                                 NaN
# 296                                                 NaN
# 299                                                 NaN
# 302                                                 NaN
# ...                                                 ...
# 831                                                 NaN
# 835                                                 NaN
# 841                                                 NaN
# 846                                                 NaN
# 847                                                 NaN
# 869                                                 NaN
# 871                                                 NaN
# 876                                                 NaN
# 880                                                 NaN
# 1002                                                NaN
# 1045                                                NaN
# 1048                                                NaN
# 1049                                                NaN
# 1050                                                NaN
# 1051                                                NaN
# 1053                                                NaN
# 1055                                                NaN
# 1059                                                NaN
# 1060                                                NaN
# 1061                                                NaN
# 1065                                                NaN
# 1071                                                NaN
# 1077                                                NaN
# 1080                                                NaN
# 1081                                                NaN
# 1083                                                NaN
# 1086                                                NaN
# 1087                                                NaN
# 1088                                                NaN
# 1232                                                NaN
#
#      Hope there will be no unscheduled meetings  \
# 2                                            Na
# 242                                         NaN
# 244                                         NaN
# 245                                         NaN
# 247                                         NaN
# 248                                         NaN
# 251                                         NaN
# 254                                         NaN
# 255                                         NaN
# 260                                         NaN
# 261                                         NaN
# 264                                         NaN
# 265                                         NaN
# 267                                         NaN
# 268                                         NaN
# 269                                         NaN
# 272                                         NaN
# 273                                         NaN
# 276                                         NaN
# 279                                         NaN
# 280                                         NaN
# 283                                         NaN
# 284                                         NaN
# 286                                         NaN
# 287                                         NaN
# 290                                         NaN
# 292                                         NaN
# 296                                         NaN
# 299                                         NaN
# 302                                         NaN
# ...                                         ...
# 831                                         NaN
# 835                                         NaN
# 841                                         NaN
# 846                                         NaN
# 847                                         NaN
# 869                                         NaN
# 871                                         NaN
# 876                                         NaN
# 880                                         NaN
# 1002                                        NaN
# 1045                                        NaN
# 1048                                        NaN
# 1049                                        NaN
# 1050                                        NaN
# 1051                                        NaN
# 1053                                        NaN
# 1055                                        NaN
# 1059                                        NaN
# 1060                                        NaN
# 1061                                        NaN
# 1065                                        NaN
# 1071                                        NaN
# 1077                                        NaN
# 1080                                        NaN
# 1081                                        NaN
# 1083                                        NaN
# 1086                                        NaN
# 1087                                        NaN
# 1088                                        NaN
# 1232                                        NaN
#
#      Can I Call you three hours before the interview and follow up on your attendance for the interview  \
# 2                                                   NaN
# 242                                                 NaN
# 244                                                 NaN
# 245                                                 NaN
# 247                                                 NaN
# 248                                                 NaN
# 251                                                 NaN
# 254                                                 NaN
# 255                                                 NaN
# 260                                                 NaN
# 261                                                 NaN
# 264                                                 NaN
# 265                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 272                                                 NaN
# 273                                                 NaN
# 276                                                 NaN
# 279                                                 NaN
# 280                                                 NaN
# 283                                                 NaN
# 284                                                 NaN
# 286                                                 NaN
# 287                                                 NaN
# 290                                                 NaN
# 292                                                 NaN
# 296                                                 NaN
# 299                                                 NaN
# 302                                                 NaN
# ...                                                 ...
# 831                                                 NaN
# 835                                                 NaN
# 841                                                 NaN
# 846                                                 NaN
# 847                                                 NaN
# 869                                                 NaN
# 871                                                 NaN
# 876                                                 NaN
# 880                                                 NaN
# 1002                                                NaN
# 1045                                                NaN
# 1048                                                NaN
# 1049                                                NaN
# 1050                                                NaN
# 1051                                                NaN
# 1053                                                NaN
# 1055                                                NaN
# 1059                                                NaN
# 1060                                                NaN
# 1061                                                NaN
# 1065                                                NaN
# 1071                                                NaN
# 1077                                                NaN
# 1080                                                NaN
# 1081                                                NaN
# 1083                                                NaN
# 1086                                                NaN
# 1087                                                NaN
# 1088                                                NaN
# 1232                                                NaN
#
#      Can I have an alternative number/ desk number. I assure you that I will not trouble you too much  \
# 2                                                   NaN
# 242                                                 NaN
# 244                                                 NaN
# 245                                                 NaN
# 247                                                 NaN
# 248                                                 NaN
# 251                                                 NaN
# 254                                                 NaN
# 255                                                 NaN
# 260                                                 NaN
# 261                                                 NaN
# 264                                                 NaN
# 265                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 272                                                 NaN
# 273                                                 NaN
# 276                                                 NaN
# 279                                                 NaN
# 280                                                 NaN
# 283                                                 NaN
# 284                                                 NaN
# 286                                                 NaN
# 287                                                 NaN
# 290                                                 NaN
# 292                                                 NaN
# 296                                                 NaN
# 299                                                 NaN
# 302                                                 NaN
# ...                                                 ...
# 831                                                 NaN
# 835                                                 NaN
# 841                                                 NaN
# 846                                                 NaN
# 847                                                 NaN
# 869                                                 NaN
# 871                                                 NaN
# 876                                                 NaN
# 880                                                 NaN
# 1002                                                NaN
# 1045                                                NaN
# 1048                                                NaN
# 1049                                                NaN
# 1050                                                NaN
# 1051                                                NaN
# 1053                                                NaN
# 1055                                                NaN
# 1059                                                NaN
# 1060                                                NaN
# 1061                                                NaN
# 1065                                                NaN
# 1071                                                NaN
# 1077                                                NaN
# 1080                                                NaN
# 1081                                                NaN
# 1083                                                NaN
# 1086                                                NaN
# 1087                                                NaN
# 1088                                                NaN
# 1232                                                NaN
#
#      Have you taken a printout of your updated resume. Have you read the JD and understood the same  \
# 2                                                   NaN
# 242                                                 NaN
# 244                                                 NaN
# 245                                                 NaN
# 247                                                 NaN
# 248                                                 NaN
# 251                                                 NaN
# 254                                                 NaN
# 255                                                 NaN
# 260                                                 NaN
# 261                                                 NaN
# 264                                                 NaN
# 265                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 272                                                 NaN
# 273                                                 NaN
# 276                                                 NaN
# 279                                                 NaN
# 280                                                 NaN
# 283                                                 NaN
# 284                                                 NaN
# 286                                                 NaN
# 287                                                 NaN
# 290                                                 NaN
# 292                                                 NaN
# 296                                                 NaN
# 299                                                 NaN
# 302                                                 NaN
# ...                                                 ...
# 831                                                 NaN
# 835                                                 NaN
# 841                                                 NaN
# 846                                                 NaN
# 847                                                 NaN
# 869                                                 NaN
# 871                                                 NaN
# 876                                                 NaN
# 880                                                 NaN
# 1002                                                NaN
# 1045                                                NaN
# 1048                                                NaN
# 1049                                                NaN
# 1050                                                NaN
# 1051                                                NaN
# 1053                                                NaN
# 1055                                                NaN
# 1059                                                NaN
# 1060                                                NaN
# 1061                                                NaN
# 1065                                                NaN
# 1071                                                NaN
# 1077                                                NaN
# 1080                                                NaN
# 1081                                                NaN
# 1083                                                NaN
# 1086                                                NaN
# 1087                                                NaN
# 1088                                                NaN
# 1232                                                NaN
#
#      Are you clear with the venue details and the landmark.  \
# 2                                                   NaN
# 242                                                 NaN
# 244                                                 NaN
# 245                                                 NaN
# 247                                                 NaN
# 248                                                 NaN
# 251                                                 NaN
# 254                                                 NaN
# 255                                                 NaN
# 260                                                 NaN
# 261                                                 NaN
# 264                                                 NaN
# 265                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 272                                                 NaN
# 273                                                 NaN
# 276                                                 NaN
# 279                                                 NaN
# 280                                                 NaN
# 283                                                 NaN
# 284                                                 NaN
# 286                                                 NaN
# 287                                                 NaN
# 290                                                 NaN
# 292                                                 NaN
# 296                                                 NaN
# 299                                                 NaN
# 302                                                 NaN
# ...                                                 ...
# 831                                                 NaN
# 835                                                 NaN
# 841                                                 NaN
# 846                                                 NaN
# 847                                                 NaN
# 869                                                 NaN
# 871                                                 NaN
# 876                                                 NaN
# 880                                                 NaN
# 1002                                                NaN
# 1045                                                NaN
# 1048                                                NaN
# 1049                                                NaN
# 1050                                                NaN
# 1051                                                NaN
# 1053                                                NaN
# 1055                                                NaN
# 1059                                                NaN
# 1060                                                NaN
# 1061                                                NaN
# 1065                                                NaN
# 1071                                                NaN
# 1077                                                NaN
# 1080                                                NaN
# 1081                                                NaN
# 1083                                                NaN
# 1086                                                NaN
# 1087                                                NaN
# 1088                                                NaN
# 1232                                                NaN
#
#      Has the call letter been shared Expected Attendance Observed Attendance  \
# 2                                NaN           Uncertain                  No
# 242                              NaN           Uncertain                 Yes
# 244                              NaN           Uncertain                  No
# 245                              NaN           Uncertain                 Yes
# 247                              NaN           Uncertain                  No
# 248                              NaN           Uncertain                 Yes
# 251                              NaN           Uncertain                 Yes
# 254                              NaN           Uncertain                  No
# 255                              NaN           Uncertain                  No
# 260                              NaN           Uncertain                 Yes
# 261                              NaN           Uncertain                  No
# 264                              NaN           Uncertain                 Yes
# 265                              NaN           Uncertain                  No
# 267                              NaN           Uncertain                  No
# 268                              NaN           Uncertain                 Yes
# 269                              NaN           Uncertain                  No
# 272                              NaN           Uncertain                 Yes
# 273                              NaN           Uncertain                 Yes
# 276                              NaN           Uncertain                  No
# 279                              NaN           Uncertain                  No
# 280                              NaN           Uncertain                 Yes
# 283                              NaN           Uncertain                  No
# 284                              NaN           Uncertain                 Yes
# 286                              NaN           Uncertain                 Yes
# 287                              NaN           Uncertain                  No
# 290                              NaN           Uncertain                 Yes
# 292                              NaN           Uncertain                  No
# 296                              NaN           Uncertain                  No
# 299                              NaN           Uncertain                 Yes
# 302                              NaN           Uncertain                  No
# ...                              ...                 ...                 ...
# 831                              NaN           Uncertain                 Yes
# 835                              NaN           Uncertain                  No
# 841                              NaN           Uncertain                  No
# 846                              NaN           Uncertain                  No
# 847                              NaN           Uncertain                 Yes
# 869                              NaN           Uncertain                 Yes
# 871                              NaN           Uncertain                  No
# 876                              NaN           Uncertain                 Yes
# 880                              NaN           Uncertain                  No
# 1002                             NaN           Uncertain                 Yes
# 1045                             NaN                 NaN                 Yes
# 1048                             NaN                 NaN                 Yes
# 1049                             NaN                 NaN                  No
# 1050                             NaN                 NaN                 Yes
# 1051                             NaN                 NaN                  no
# 1053                             NaN           Uncertain                 yes
# 1055                             NaN           Uncertain                  No
# 1059                             NaN           Uncertain                 yes
# 1060                             NaN           Uncertain                 yes
# 1061                             NaN           Uncertain                  No
# 1065                             NaN           Uncertain                 Yes
# 1071                             NaN           Uncertain                  No
# 1077                             NaN           Uncertain                  No
# 1080                             NaN           Uncertain                 yes
# 1081                             NaN           Uncertain                  No
# 1083                             NaN           Uncertain                 Yes
# 1086                             NaN           Uncertain                  No
# 1087                             NaN           Uncertain                 No
# 1088                             NaN           Uncertain                  No
# 1232                             NaN           Uncertain                 Yes
#
#      Marital Status
# 2            Single
# 242          Single
# 244          Single
# 245         Married
# 247          Single
# 248          Single
# 251          Single
# 254          Single
# 255          Single
# 260          Single
# 261          Single
# 264         Married
# 265          Single
# 267          Single
# 268          Single
# 269         Married
# 272          Single
# 273         Married
# 276          Single
# 279         Married
# 280          Single
# 283          Single
# 284         Married
# 286          Single
# 287         Married
# 290         Married
# 292         Married
# 296          Single
# 299          Single
# 302          Single
# ...             ...
# 831          Single
# 835         Married
# 841          Single
# 846          Single
# 847          Single
# 869          Single
# 871          Single
# 876          Single
# 880          Single
# 1002         Single
# 1045         Single
# 1048        Married
# 1049         Single
# 1050         Single
# 1051         Single
# 1053         Single
# 1055        Married
# 1059         Single
# 1060         Single
# 1061         Single
# 1065        Married
# 1071         Single
# 1077         Single
# 1080         Single
# 1081         Single
# 1083        Married
# 1086         Single
# 1087         Single
# 1088         Single
# 1232         Single
#
# [204 rows x 21 columns]

# %% [markdown]
# Replace NAN by Na

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1233 entries, 0 to 1232
# Data columns (total 21 columns):
# Client name                                                                                           1233 non-null object
# Industry                                                                                              1233 non-null object
# Location                                                                                              1233 non-null object
# Position to be closed                                                                                 1233 non-null object
# Nature of Skillset                                                                                    1233 non-null object
# Interview Type                                                                                        1233 non-null object
# Gender                                                                                                1233 non-null object
# Candidate Current Location                                                                            1233 non-null object
# Candidate Job Location                                                                                1233 non-null object
# Interview Venue                                                                                       1233 non-null object
# Candidate Native location                                                                             1233 non-null object
# Have you obtained the necessary permission to start at the required time                              1029 non-null object
# Hope there will be no unscheduled meetings                                                            986 non-null object
# Can I Call you three hours before the interview and follow up on your attendance for the interview    986 non-null object
# Can I have an alternative number/ desk number. I assure you that I will not trouble you too much      986 non-null object
# Have you taken a printout of your updated resume. Have you read the JD and understood the same        985 non-null object
# Are you clear with the venue details and the landmark.                                                985 non-null object
# Has the call letter been shared                                                                       988 non-null object
# Expected Attendance                                                                                   1228 non-null object
# Observed Attendance                                                                                   1233 non-null object
# Marital Status                                                                                        1233 non-null object
# dtypes: object(21)
# memory usage: 211.9+ KB

# %%
df['Hope there will be no unscheduled meetings'].unique()
# Out:
# array(['Yes', 'Na', 'No', nan, 'yes', 'Not Sure', 'cant Say', 'Not sure'],
#       dtype=object)

# %%
df['Hope there will be no unscheduled meetings'].fillna('Na', inplace=True)
df['Hope there will be no unscheduled meetings'].replace(['Yes', 'yes'],'Yes', inplace=True)
df['Hope there will be no unscheduled meetings'].replace(['Not Sure', 'cant Say', 'Not sure'],'Not sure', inplace=True)
df['Hope there will be no unscheduled meetings'].value_counts()
# Out:
# Yes         954
# Na          267
# No            6
# Not sure      6
# Name: Hope there will be no unscheduled meetings, dtype: int64

# %%
df['Can I Call you three hours before the interview and follow up on your attendance for the interview'].unique()
# Out:
# array(['Yes', nan, 'No', 'No Dont', 'Na', 'yes'], dtype=object)

# %%
df['Can I Call you three hours before the interview and follow up on your attendance for the interview'].fillna('Na', inplace=True)
df['Can I Call you three hours before the interview and follow up on your attendance for the interview'].replace(['Yes','yes'],'Yes', inplace=True)
df['Can I Call you three hours before the interview and follow up on your attendance for the interview'].replace(['No','No Dont'],'No', inplace=True)
df['Can I Call you three hours before the interview and follow up on your attendance for the interview'].value_counts()
# Out:
# Yes    955
# Na     267
# No      11
# Name: Can I Call you three hours before the interview and follow up on your attendance for the interview, dtype: int64

# %%
df['Can I have an alternative number/ desk number. I assure you that I will not trouble you too much'].unique()
# Out:
# array(['Yes', nan, 'No', 'No I have only thi number', 'na', 'yes', 'Na'],
#       dtype=object)

# %%
df['Can I have an alternative number/ desk number. I assure you that I will not trouble you too much'].fillna('Na', inplace=True)
df['Can I have an alternative number/ desk number. I assure you that I will not trouble you too much'].replace(['Yes','yes'],'Yes', inplace=True)
df['Can I have an alternative number/ desk number. I assure you that I will not trouble you too much'].replace(['No', 'No I have only thi number'],'No', inplace=True)
df['Can I have an alternative number/ desk number. I assure you that I will not trouble you too much'].replace(['Na','na'],'Na', inplace=True)
df['Can I have an alternative number/ desk number. I assure you that I will not trouble you too much'].value_counts()
# Out:
# Yes    937
# Na     267
# No      29
# Name: Can I have an alternative number/ desk number. I assure you that I will not trouble you too much, dtype: int64

# %%
df['Have you taken a printout of your updated resume. Have you read the JD and understood the same'].unique()
# Out:
# array(['Yes', nan, 'No', 'No- will take it soon', 'Not yet', 'na', 'yes',
#        'Na', 'Not Yet'], dtype=object)

# %%
df['Have you taken a printout of your updated resume. Have you read the JD and understood the same'].fillna('Na', inplace=True)
df['Have you taken a printout of your updated resume. Have you read the JD and understood the same'].replace(['Yes','yes'],'Yes', inplace=True)
df['Have you taken a printout of your updated resume. Have you read the JD and understood the same'].replace(['No', 'No- will take it soon','Not yet','Not Yet'],'No', inplace=True)
df['Have you taken a printout of your updated resume. Have you read the JD and understood the same'].replace(['Na','na'],'Na', inplace=True)
df['Have you taken a printout of your updated resume. Have you read the JD and understood the same'].value_counts()
# Out:
# Yes    942
# Na     268
# No      23
# Name: Have you taken a printout of your updated resume. Have you read the JD and understood the same, dtype: int64

# %%
df['Are you clear with the venue details and the landmark.'].unique()
# Out:
# array(['Yes', nan, 'No', 'No- I need to check', 'na', 'yes', 'Na', 'no'],
#       dtype=object)

# %%
df['Are you clear with the venue details and the landmark.'].fillna('Na', inplace=True)
df['Are you clear with the venue details and the landmark.'].replace(['Yes','yes'],'Yes', inplace=True)
df['Are you clear with the venue details and the landmark.'].replace(['No', 'No- I need to check','no'],'No', inplace=True)
df['Are you clear with the venue details and the landmark.'].replace(['Na','na'],'Na', inplace=True)
df['Are you clear with the venue details and the landmark.'].value_counts()
# Out:
# Yes    948
# Na     268
# No      17
# Name: Are you clear with the venue details and the landmark., dtype: int64

# %%
df['Has the call letter been shared'].unique()
# Out:
# array(['Yes', nan, 'Havent Checked', 'No', 'Need To Check', 'Not sure',
#        'Yet to Check', 'Not Sure', 'Not yet', 'no', 'na', 'yes', 'Na'],
#       dtype=object)

# %%
df['Has the call letter been shared'].fillna('Na', inplace=True)
df['Has the call letter been shared'].replace(['Yes','yes'],'Yes', inplace=True)
df['Has the call letter been shared'].replace(['No', 'No- I need to check','no'],'No', inplace=True)
df['Has the call letter been shared'].replace(['Havent Checked', 'Need To Check', 'Not sure','Yet to Check', 'Not Sure', 'Not yet'],'Not sure', inplace=True)
df['Has the call letter been shared'].replace(['Na','na'],'Na', inplace=True)
df['Has the call letter been shared'].value_counts()
# Out:
# Yes         934
# Na          265
# No           18
# Not sure     16
# Name: Has the call letter been shared, dtype: int64

# %%
df['Expected Attendance'].unique()
# Out:
# array(['Yes', 'Uncertain', 'No', 'NO', 'yes', nan, '11:00 AM', '10.30 Am'],
#       dtype=object)

# %%
df['Expected Attendance'].fillna('Uncertain', inplace=True)
df['Expected Attendance'].replace(['Yes','yes','yes ','11:00 AM', '10.30 Am'],'Yes', inplace=True)
df['Expected Attendance'].replace(['No',  'no', 'No ', 'NO', 'no '],'No', inplace=True)
df['Expected Attendance'].value_counts()
# Out:
# Yes          885
# Uncertain    255
# No            93
# Name: Expected Attendance, dtype: int64

# %%
df['Observed Attendance'].value_counts()
# Out:
# Yes     701
# No      401
# yes      81
# NO       35
# no        7
# No        6
# no        1
# yes       1
# Name: Observed Attendance, dtype: int64

# %%
df['Observed Attendance'].fillna('Na', inplace=True)
df['Observed Attendance'].replace(['Yes','yes','yes '],1, inplace=True)
df['Observed Attendance'].replace(['No',  'no', 'No ', 'NO', 'no '],0, inplace=True)
df['Observed Attendance'].value_counts()
# Out:
# 1    783
# 0    450
# Name: Observed Attendance, dtype: int64

# %%
df.shape
# Out:
# (1233, 21)

# %% [markdown]
# ## Now Data Pre-Processing for Modelling

# %%
df1=pd.get_dummies(df.drop('Observed Attendance',axis=1), drop_first=True)

# %%
df.shape
# Out:
# (1233, 21)

# %%
df1.shape
# Out:
# (1233, 192)

# %%
df1.head()
# Out:
#    Client name_Astrazeneca  Client name_Barclays  Client name_Flextronics  \
# 0                        0                     0                        0
# 1                        0                     0                        0
# 2                        0                     0                        0
# 3                        0                     0                        0
# 4                        0                     0                        0
#
#    Client name_Hospira  Client name_IT  Client name_Pfizer  \
# 0                    1               0                   0
# 1                    1               0                   0
# 2                    1               0                   0
# 3                    1               0                   0
# 4                    1               0                   0
#
#    Client name_Prodapt  Client name_Standard Chartered Bank  Client name_UST  \
# 0                    0                                    0                0
# 1                    0                                    0                0
# 2                    0                                    0                0
# 3                    0                                    0                0
# 4                    0                                    0                0
#
#    Client name_Williams Lea  ...  \
# 0                         0  ...
# 1                         0  ...
# 2                         0  ...
# 3                         0  ...
# 4                         0  ...
#
#    Have you taken a printout of your updated resume. Have you read the JD and understood the same_No  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  1
# 4                                                  0
#
#    Have you taken a printout of your updated resume. Have you read the JD and understood the same_Yes  \
# 0                                                  1
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  1
#
#    Are you clear with the venue details and the landmark._No  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Are you clear with the venue details and the landmark._Yes  \
# 0                                                  1
# 1                                                  1
# 2                                                  0
# 3                                                  1
# 4                                                  1
#
#    Has the call letter been shared_No  \
# 0                                   0
# 1                                   0
# 2                                   0
# 3                                   0
# 4                                   0
#
#    Has the call letter been shared_Not sure  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
#
#    Has the call letter been shared_Yes  Expected Attendance_Uncertain  \
# 0                                    1                              0
# 1                                    1                              0
# 2                                    0                              1
# 3                                    1                              1
# 4                                    1                              1
#
#    Expected Attendance_Yes  Marital Status_Single
# 0                        1                      1
# 1                        1                      1
# 2                        0                      1
# 3                        0                      1
# 4                        0                      0
#
# [5 rows x 192 columns]

# %%
df2=pd.concat([df1,df['Observed Attendance']], axis=1)

# %%
df2.head(2)
# Out:
#    Client name_Astrazeneca  Client name_Barclays  Client name_Flextronics  \
# 0                        0                     0                        0
# 1                        0                     0                        0
#
#    Client name_Hospira  Client name_IT  Client name_Pfizer  \
# 0                    1               0                   0
# 1                    1               0                   0
#
#    Client name_Prodapt  Client name_Standard Chartered Bank  Client name_UST  \
# 0                    0                                    0                0
# 1                    0                                    0                0
#
#    Client name_Williams Lea  ...  \
# 0                         0  ...
# 1                         0  ...
#
#    Have you taken a printout of your updated resume. Have you read the JD and understood the same_Yes  \
# 0                                                  1
# 1                                                  1
#
#    Are you clear with the venue details and the landmark._No  \
# 0                                                  0
# 1                                                  0
#
#    Are you clear with the venue details and the landmark._Yes  \
# 0                                                  1
# 1                                                  1
#
#    Has the call letter been shared_No  \
# 0                                   0
# 1                                   0
#
#    Has the call letter been shared_Not sure  \
# 0                                         0
# 1                                         0
#
#    Has the call letter been shared_Yes  Expected Attendance_Uncertain  \
# 0                                    1                              0
# 1                                    1                              0
#
#    Expected Attendance_Yes  Marital Status_Single  Observed Attendance
# 0                        1                      1                    0
# 1                        1                      1                    0
#
# [2 rows x 193 columns]

# %%
x = df2.drop(['Observed Attendance'], axis=1)
y = df2['Observed Attendance']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=100)

# %% [markdown]
# ## Lets start modelling with KNN

# %%
for i in range(1,50):
    from sklearn.neighbors import KNeighborsClassifier
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred = knn.predict(X_test)
    from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
    #print(confusion_matrix(y_test,pred))
    #print(classification_report(y_test,pred))
    print(i,accuracy_score(y_test,pred))
# Out:
# 1 0.5918918918918918
# 2 0.5756756756756757
# 3 0.6243243243243243
# 4 0.6081081081081081
# 5 0.6702702702702703
# 6 0.654054054054054
# 7 0.6459459459459459
# 8 0.6378378378378379
# 9 0.6567567567567567
# 10 0.6702702702702703
# 11 0.6756756756756757
# 12 0.6783783783783783
# 13 0.6756756756756757
# 14 0.6810810810810811
# 15 0.6810810810810811
# 16 0.6783783783783783
# 17 0.6702702702702703
# 18 0.6783783783783783
# 19 0.6567567567567567
# 20 0.672972972972973
# 21 0.6702702702702703
# 22 0.6702702702702703
# 23 0.6783783783783783
# 24 0.6864864864864865
# 25 0.6702702702702703
# 26 0.6837837837837838
# 27 0.6783783783783783
# 28 0.6702702702702703
# 29 0.6702702702702703
# 30 0.6756756756756757
# 31 0.6756756756756757
# 32 0.6810810810810811
# 33 0.6702702702702703
# 34 0.6756756756756757
# 35 0.6702702702702703
# 36 0.6810810810810811
# 37 0.6783783783783783
# 38 0.6837837837837838
# 39 0.6837837837837838
# 40 0.6918918918918919
# 41 0.6891891891891891
# 42 0.6918918918918919
# 43 0.6810810810810811
# 44 0.6945945945945946
# 45 0.7
# 46 0.6918918918918919
# 47 0.6810810810810811
# 48 0.7
# 49 0.6945945945945946

# %%
from sklearn.model_selection import RandomizedSearchCV
par={'n_neighbors': list(range(1,150)), 'weights' :['distance','uniform']}
RDSCV = RandomizedSearchCV(KNeighborsClassifier(), param_distributions=par,n_jobs=-1, cv=7)
RDSCV.fit(X_train,y_train)
pred = RDSCV.predict(X_test)
params = RDSCV.best_params_
score = RDSCV.best_score_
print(params,"Accuracy: ",score)
print('Accuracy Score: ',accuracy_score(y_test,pred))
# Out:
# {'weights': 'uniform', 'n_neighbors': 88} Accuracy:  0.6732329084588644
# Accuracy Score:  0.6918918918918919

# %%
    from sklearn.neighbors import KNeighborsClassifier
    knn = KNeighborsClassifier(n_neighbors=14)
    knn.fit(X_train,y_train)
    pred = knn.predict(X_test)
    from sklearn.metrics import classification_report,confusion_matrix
    print('Accuracy Score: ',accuracy_score(y_test,pred))
# Out:
# Accuracy Score:  0.6810810810810811

# %% [markdown]
# ## Lets try Support Vector Machines Classifier SVC

# %%
from sklearn.svm import SVC
svc_model = SVC()
svc_model.fit(X_train,y_train)
predictions = svc_model.predict(X_test)
print('Accuracy Score: ',accuracy_score(y_test,predictions))
# Out:
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Accuracy Score:  0.7162162162162162

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [0.1,1, 10, 100], 'gamma': [1,0.1,0.01,0.001]} 
grid = GridSearchCV(SVC(),param_grid,verbose=0)
grid.fit(X_train,y_train)
grid_predictions = grid.predict(X_test)
print('Accuracy Score: ',accuracy_score(y_test,grid_predictions))
# Out:
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# Accuracy Score:  0.7162162162162162

# %% [markdown]
# ## Finally Lets Model it with Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()
LR.fit(X_train,y_train)
LRpred = LR.predict(X_test)
print('Accuracy: ',accuracy_score(y_test,LRpred))
# Out:
# Accuracy:  0.7162162162162162
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression(penalty='l1',C=0.2)
LR.fit(X_train,y_train)
LRpred = LR.predict(X_test)
print('Accuracy: ',accuracy_score(y_test,LRpred))
# Out:
# Accuracy:  0.7405405405405405
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
print(classification_report(y_test,LRpred))
print(confusion_matrix(y_test,LRpred))
print('Accuracy: ',accuracy_score(y_test,LRpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.37      0.52       137
#            1       0.72      0.96      0.82       233
#
#    micro avg       0.74      0.74      0.74       370
#    macro avg       0.78      0.66      0.67       370
# weighted avg       0.76      0.74      0.71       370
#
# [[ 51  86]
#  [ 10 223]]
# Accuracy:  0.7405405405405405

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [0.1,.2,.4,.9,1,10] , 'penalty':['l1', 'l2']}
grid = GridSearchCV(LogisticRegression(),param_grid,cv=10)
grid.fit(X_train,y_train)
grid_predictions = grid.predict(X_test)
print('Accuracy Score: ',accuracy_score(y_test,grid_predictions))
# Out:
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Accuracy Score:  0.7243243243243244
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
print("Avg Accuracy: ",grid.best_score_ ,"  Parameters: ", grid.best_params_)
# Out:
# Avg Accuracy:  0.697566628041715   Parameters:  {'C': 0.1, 'penalty': 'l1'}

# %%
from sklearn.model_selection import cross_validate
cv_results = cross_validate(LogisticRegression(penalty='l1',C=0.2), X_train,y_train, cv=8)
cv_results['test_score'].mean()
# Out:
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\m0092071\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.6837608288001625
